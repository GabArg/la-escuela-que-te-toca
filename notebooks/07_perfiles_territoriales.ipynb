# %% [markdown]
# # Perfiles educativos territoriales
# Auditoría multidimensional sin score, ranking ni causalidad.

# %%
from src.features.perfiles_territoriales import write_profiles
from src.analysis.perfiles_territoriales import coverage_summary, concurrent_signals, contrasting_profiles
profiles, signals = write_profiles()
profiles.shape

# %%
coverage_summary(profiles)

# %%
concurrent_signals(profiles).head(20)

# %%
contrasting_profiles(profiles)

# %% [markdown]
# ## Conclusión provisional
# Las dimensiones deben mostrarse separadas. La cobertura parcial de Matemática limita comparaciones y ninguna bandera debe interpretarse como diagnóstico causal.
