# %% [markdown]
# # 03 — Cruces territoriales
#
# Integración de indicadores educativos con unidades y atributos territoriales.
#
# > **TODO:** definir claves geográficas, niveles de agregación y criterios de comparabilidad.

# %%
# TODO: implementar cruces luego de validar nomencladores y geometrías.
