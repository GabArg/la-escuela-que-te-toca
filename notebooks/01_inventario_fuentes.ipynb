# %% [markdown]
# # 01 — Inventario de fuentes
#
# Relevamiento y evaluación inicial de fuentes de datos abiertos oficiales.
#
# > **TODO:** documentar cobertura, granularidad, periodicidad, licencias y calidad de cada fuente antes de ingerir datos.

# %%
# TODO: cargar docs/fuentes/inventario_fuentes.csv cuando existan registros validados.
