# %% [markdown]
# # 04 — Clusters y patrones
#
# Análisis exploratorio de agrupamientos y patrones territoriales.
#
# > **TODO:** justificar variables, transformaciones, método, validación y límites interpretativos antes de modelar.

# %%
# TODO: implementar modelos únicamente sobre datos procesados y validados.
